# %% [markdown]
# <a href="https://colab.research.google.com/github/urous3814/Sorabol-SharingCamp/blob/main/09/13Colab_3day.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.font_manager as fm 
# !apt-get install fonts-nanum 
fm._rebuild()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm 
fontpath='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name=fm.FontProperties(fname=fontpath).get_name() 
plt.rc('font',family=font_name) 
plt.rc('axes', unicode_minus=False)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/colab/202108_202108_연령별인구현황_월간 (1).csv', encoding='cp949', thousands = ',')
df
# Out:
#                           행정구역  ...  2021년08월_여_100세 이상
# 0          서울특별시  (1100000000)  ...                1893
# 1       서울특별시 종로구 (1111000000)  ...                  37
# 2        서울특별시 중구 (1114000000)  ...                  44
# 3       서울특별시 용산구 (1117000000)  ...                  68
# 4       서울특별시 성동구 (1120000000)  ...                  53
# ..                         ...  ...                 ...
# 288      경상남도 거창군 (4888000000)  ...                  20
# 289      경상남도 합천군 (4889000000)  ...                  27
# 290      제주특별자치도  (5000000000)  ...                 198
# 291   제주특별자치도 제주시 (5011000000)  ...                 129
# 292  제주특별자치도 서귀포시 (5013000000)  ...                  69
#
# [293 rows x 310 columns]

# %%
df[df['2021년08월_계_총인구수'] == 0]
# Out:
#                            행정구역  ...  2021년08월_여_100세 이상
# 54   인천광역시 중구영종출장소 (2811400000)  ...                   0
# 55   인천광역시 중구용유출장소 (2811800000)  ...                   0
# 63   인천광역시 서구검단출장소 (2826500000)  ...                   0
# 87          북부출장소  (4110500000)  ...                   0
# 104      경기도 송탄출장소 (4122200000)  ...                   0
# 105      경기도 안중출장소 (4122400000)  ...                   0
# 117      경기도 풍양출장소 (4136200000)  ...                   0
# 132   경기도 화성시동부출장소 (4159200000)  ...                   0
# 133   경기도 화성시동탄출장소 (4159400000)  ...                   0
# 142         동해출장소  (4210500000)  ...                   0
# 199  전라북도 전주시효자출장소 (4511800000)  ...                   0
# 202  전라북도 익산시함열출장소 (4514500000)  ...                   0
# 273   경상남도 사천남양출장소 (4824500000)  ...                   0
# 275     경상남도 장유출장소 (4825200000)  ...                   0
# 279  경상남도 양산시웅상출장소 (4833200000)  ...                   0
#
# [15 rows x 310 columns]

# %%
df = df[df['2021년08월_계_총인구수'] != 0]
df
# Out:
#                           행정구역  ...  2021년08월_여_100세 이상
# 0          서울특별시  (1100000000)  ...                1893
# 1       서울특별시 종로구 (1111000000)  ...                  37
# 2        서울특별시 중구 (1114000000)  ...                  44
# 3       서울특별시 용산구 (1117000000)  ...                  68
# 4       서울특별시 성동구 (1120000000)  ...                  53
# ..                         ...  ...                 ...
# 288      경상남도 거창군 (4888000000)  ...                  20
# 289      경상남도 합천군 (4889000000)  ...                  27
# 290      제주특별자치도  (5000000000)  ...                 198
# 291   제주특별자치도 제주시 (5011000000)  ...                 129
# 292  제주특별자치도 서귀포시 (5013000000)  ...                  69
#
# [278 rows x 310 columns]

# %%
df[df['행정구역'].str.contains('노원구')]
# Out:
#                       행정구역  2021년08월_계_총인구수  ...  2021년08월_여_99세  2021년08월_여_100세 이상
# 11  서울특별시 노원구 (1135000000)           514050  ...              31                 107
#
# [1 rows x 310 columns]

# %%
tmp = df[df['행정구역'].str.contains('노원구')]
tmp2 = tmp.loc[:,'2021년08월_계_0세':'2021년08월_계_100세 이상'] 
tmp3 = tmp2.to_numpy()
town_np = tmp3[0]
town_np
# Out:
# array([ 2185,  2273,  2435,  2615,  2989,  3380,  3668,  3658,  3905,
#         4176,  4499,  4290,  4558,  5229,  5169,  5039,  5192,  5724,
#         5556,  5865,  6842,  7300,  7185,  7652,  7337,  7169,  6884,
#         6905,  7024,  6754,  6252,  6289,  6152,  5921,  5812,  6110,
#         6001,  6447,  6918,  7483,  7596,  7916,  7499,  7269,  7705,
#         7549,  8662,  9448,  9566,  9736, 10430,  9843,  9794,  9225,
#         8247,  8074,  7936,  7321,  8355,  7781,  8911,  8552,  7831,
#         7486,  7264,  6798,  7068,  5727,  5142,  5410,  3983,  4361,
#         4342,  4283,  4240,  2988,  3226,  3116,  3299,  3472,  2790,
#         2443,  2307,  2079,  1761,  1564,  1337,  1105,   931,   812,
#          604,   483,   402,   342,   219,   137,    99,    86,    82,
#           45,   129])

# %%
import matplotlib.pyplot as plt 
plt.title('노원구의 인구 구조', fontsize=25)
plt.plot(town_np) 
plt.show()

# %%
M_np = df[df['행정구역'].str.contains('노원구')].loc[:,'2021년08월_남_0세':'2021년08월_남_100세 이상'].to_numpy()[0]
F_np = df[df['행정구역'].str.contains('노원구')].oc[:,'2021년08월_여_0세':'2021년08월_여_100세 이상'].to_numpy()[0]
plt.title('노원구의 남녀 인구 구조', fontsize=25)
plt.plot(M_np, label='남자')
plt.plot(F_np, label='여자')
plt.legend()
plt.show()

# %%
data = M_np - F_np
plt.figure(figsize=(10, 5))
plt.title('노원구의 남자 여자의 인구수 차이 (남자-여자)', fontsize=25)
plt.bar(range(101), data)
plt.show()

# %%
df[df['행정구역'].str.contains('1100000000')]
# Out:
#                   행정구역  2021년08월_계_총인구수  ...  2021년08월_여_99세  2021년08월_여_100세 이상
# 0  서울특별시  (1100000000)          9550227  ...             634                1893
#
# [1 rows x 310 columns]

# %%
M2_np = df[df['행정구역'].str.contains('1100000000')].loc[:, '2021년08월_남_0세':'2021년08월_남_100세 이상'].to_numpy()[0]
F2_np = df[df['행정구역'].str.contains('1100000000')].loc[:, '2021년08월_여_0세':'2021년08월_여_100세 이상'].to_numpy()[0]
data2 = M2_np - F2_np
plt.figure(figsize=(10, 6))
plt.title('서울특별시의 남자 여자의 인구수 차이 (남자-여자)', fontsize=25)
plt.bar(range(101), data2)
plt.plot(range(101), data, 'r')
plt.show()

# %%
M3_np = df[df['행정구역'].str.contains('성북구')].loc[:, '2021년08월_남_0세':'2021년08월_남_100세 이상'].to_numpy()[0]
F3_np = df[df['행정구역'].str.contains('성북구')].loc[:, '2021년08월_여_0세':'2021년08월_여_100세 이상'].to_numpy()[0]
data3 = M3_np - F3_np
plt.figure(figsize=(10, 6))
plt.title('성북구의 남자 여자의 인구수 차이 (남자-여자)', fontsize=25)
plt.bar(range(101), data3)
plt.plot(range(101), data, 'r')
plt.show()

# %%
df2 = df.loc[:, '행정구역':'2021년08월_계_100세 이상']
df2.head()
# Out:
#                      행정구역  2021년08월_계_총인구수  ...  2021년08월_계_99세  2021년08월_계_100세 이상
# 0     서울특별시  (1100000000)          9550227  ...             819                2516
# 1  서울특별시 종로구 (1111000000)           145551  ...              34                  54
# 2   서울특별시 중구 (1114000000)           122852  ...              20                  60
# 3  서울특별시 용산구 (1117000000)           224977  ...              36                  95
# 4  서울특별시 성동구 (1120000000)           288214  ...              25                  82
#
# [5 rows x 104 columns]

# %%
for col in range(3, 104) :
   df2.iloc[:,col] = df2.iloc[:,col] / df2.iloc[:,1]
df2.head()
# Out:
#                      행정구역  2021년08월_계_총인구수  ...  2021년08월_계_99세  2021년08월_계_100세 이상
# 0     서울특별시  (1100000000)          9550227  ...        0.000086            0.000263
# 1  서울특별시 종로구 (1111000000)           145551  ...        0.000234            0.000371
# 2   서울특별시 중구 (1114000000)           122852  ...        0.000163            0.000488
# 3  서울특별시 용산구 (1117000000)           224977  ...        0.000160            0.000422
# 4  서울특별시 성동구 (1120000000)           288214  ...        0.000087            0.000285
#
# [5 rows x 104 columns]

# %%
town_df = df2[df2['행정구역'].str.contains('노원구')]
town_df
# Out:
#                       행정구역  2021년08월_계_총인구수  ...  2021년08월_계_99세  2021년08월_계_100세 이상
# 11  서울특별시 노원구 (1135000000)           514050  ...        0.000088            0.000251
#
# [1 rows x 104 columns]

# %%
list_mse = []
for i in range(len(df2)):
  list_mse.append(((df2.iloc[i,3:] - town_df.iloc[0,3:])**2).mean())
df2['MSE'] = list_mse
df2.head()
# Out:
#                      행정구역  2021년08월_계_총인구수  ...  2021년08월_계_100세 이상       MSE
# 0     서울특별시  (1100000000)          9550227  ...            0.000263  0.000003
# 1  서울특별시 종로구 (1111000000)           145551  ...            0.000371  0.000003
# 2   서울특별시 중구 (1114000000)           122852  ...            0.000488  0.000006
# 3  서울특별시 용산구 (1117000000)           224977  ...            0.000422  0.000005
# 4  서울특별시 성동구 (1120000000)           288214  ...            0.000285  0.000005
#
# [5 rows x 105 columns]

# %%
df3 = df2.sort_values('MSE')
df3.head()
# Out:
#                           행정구역  ...           MSE
# 11      서울특별시 노원구 (1135000000)  ...  0.000000e+00
# 197  전라북도 전주시 완산구 (4511100000)  ...  4.970589e-07
# 48       대구광역시 북구 (2723000000)  ...  6.158621e-07
# 43         대구광역시  (2700000000)  ...  6.614631e-07
# 164  충청북도 청주시 서원구 (4311200000)  ...  6.753834e-07
#
# [5 rows x 105 columns]

# %%
plt.figure(figsize = (10, 6))
plt.title('노원구와 가장 유사한 인구구조를 가진 지역과 가장 먼 인구구조를 가진 지역만을 찾아왔으나 이제는 더이상 존재하지 않으니 이를 어찌할꼬...', fontsize = 25)
plt.plot(df3.iloc[0,3:104].to_numpy(), label = df3.iloc[0,0])
plt.plot(df3.iloc[1,3:104].to_numpy(), label = df3.iloc[1,0])
plt.plot(df3.iloc[-1,3:104].to_numpy(), label = df3.iloc[-1,0])
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,6))
plt.title('노원구와 가장 유사한 인구구조를 가진 지역과 가장 먼 인구구조를 가진 지역만을 찾아왔으나 이제는 더이상 존재하지 않으니 이를 어찌할꼬...', fontsize = 25)
plt.plot(df3.iloc[0,3:104].to_numpy(), label = df3.iloc[0,0].split('(')[0])
plt.plot(df3.iloc[1,3:104].to_numpy(), label = df3.iloc[1,0].split('(')[0])
plt.plot(df3.iloc[-1,3:104].to_numpy(), label = df3.iloc[-1,0].split('(')[0])
plt.legend()
plt.show()
